# %% [markdown]
# ## FORECASTING CON REDES LSTM - MODELO MULTIVARIADO - UNISTEP

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('./data/BTCUSDT_data_fixed.csv')
df
# Out:
# c:\Users\cmglezpdev2\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                  Open time      Open      High       Low     Close  \
# 0      2017-09-01 00:00:00   4689.89   4767.00   4689.89   4714.73
# 1      2017-09-01 04:00:00   4714.73   4734.99   4654.88   4707.50
# 2      2017-09-01 08:00:00   4715.00   4798.46   4708.09   4775.00
# 3      2017-09-01 12:00:00   4775.00   4839.92   4725.81   4803.83
# 4      2017-09-01 16:00:00   4756.46   4815.67   4738.94   4813.24
# ...                    ...       ...       ...       ...       ...
# 14238  2024-03-01 00:00:00  61130.99  61749.00  60777.00  61105.91
# 14239  2024-03-01 04:00:00  61105.92  61772.82  61061.11  61434.00
# 14240  2024-03-01 08:00:00  61434.00  62243.53  61316.67  61863.72
# 14241  2024-03-01 12:00:00  61863.71  62677.06  61131.01  61263.99
# 14242  2024-03-01 16:00:00  61263.98  61539.99  61234.00  61274.35
#
#             Volume  Number of trades
# 0        75.647978               623
# 1       101.226134               541
# 2       130.966655               810
# 3        68.887712               518
# 4        96.951623               893
# ...            ...               ...
# 14238  6345.576410            243343
# 14239  5719.405040            265072
# 14240  8452.279910            322392
# 14241  9971.279050            479317
# 14242   920.575700             32262
#
# [14243 rows x 7 columns]

# %% [markdown]
# ## 5. Pre-procesamiento
#
# Implica:
#
# 1. Partición en train/val/test (80%, 10%, 10%)
# 2. Generación del dataset supervisado: entrada y salida del modelo
# 3. Escalamiento
#
# Veamos cada una de estas fases.

# %%
# primero eliminamos la variable del tiempo
df = df.drop(columns=['Open time'])
df
# Out:
#            Open      High       Low     Close       Volume  Number of trades
# 0       4689.89   4767.00   4689.89   4714.73    75.647978               623
# 1       4714.73   4734.99   4654.88   4707.50   101.226134               541
# 2       4715.00   4798.46   4708.09   4775.00   130.966655               810
# 3       4775.00   4839.92   4725.81   4803.83    68.887712               518
# 4       4756.46   4815.67   4738.94   4813.24    96.951623               893
# ...         ...       ...       ...       ...          ...               ...
# 14238  61130.99  61749.00  60777.00  61105.91  6345.576410            243343
# 14239  61105.92  61772.82  61061.11  61434.00  5719.405040            265072
# 14240  61434.00  62243.53  61316.67  61863.72  8452.279910            322392
# 14241  61863.71  62677.06  61131.01  61263.99  9971.279050            479317
# 14242  61263.98  61539.99  61234.00  61274.35   920.575700             32262
#
# [14243 rows x 6 columns]

# %% [markdown]
# ### 5.1. Partición del set en entrenamiento, validación y prueba
#
# A diferencia de otros modelos de Machine Learning, en el caso de series de tiempo **se debe garantizar que se generan las particiones sin mezclar aleatoriamente los datos**.
#
# Recordemos además que:
# - El set de entrenamiento (*train*) se usará para encontrar los parámetros del modelo
# - El set de validación (*val*) para verificar que no haya *under/over-fitting* del modelo y para ajustar sus hiperparámetros
# - El set de prueba (*test*) para poner a prueba el mejor modelo encontrado durante el entrenamiento/validación

# %%
def train_val_test_split(dataframe, tr_size=0.8, vl_size=0.1, ts_size=0.1):
  """
  Split a time series into train, validation and test sets.
  """
  N = dataframe.shape[0]
  train_size = int(tr_size * N)
  val_size = int(vl_size * N)
  test_size = N - train_size - val_size

  train = dataframe[:train_size]
  val = dataframe[train_size:train_size + val_size]
  test = dataframe[train_size + val_size:]

  return train, val, test

# %%
tr, vl, ts = train_val_test_split(df)

print(f'Training set size: {tr.shape}')
print(f'Validation set size: {vl.shape}')
print(f'Testing set size: {ts.shape}')
# Out:
# Training set size: (11394, 6)
# Validation set size: (1424, 6)
# Testing set size: (1425, 6)

# %%
# Dibujar uno de las covariables
covar = 4 # volume
col = df.columns[covar]

fig, ax = plt.subplots(figsize=(16, 5))
ax.plot(tr[col], label='Train')
ax.plot(vl[col], label='Validation')
ax.plot(ts[col], label='Test')
plt.legend()

# %%
import numpy as np
def create_supervised_dataset(array: np.array, input_length: int, output_length: int):
  """
  Creates a supervised dataset with inputs (X) and outputs (Y) requires for LSTM networks.

  Args:
    array (numpy.ndarray): The input array with size N x features (N:amount of data, f: amount of features).
    input_length (int): Consecutive time instants of the time serie(s) used to feed the model
    output_length (int): Instants of time to be forecast (model output)

  Returns:
    numpy.ndarray: Instants of time to be forecast (model output)
  """

  X, Y = [], []
  shape = array.shape
  if len(shape) == 1:
    # we have a single time serie (univariado)
    rows, cols = array.shape[0], 1
    array = array.reshape(rows, cols)
  else:
    # we have multiple time series (multivariado)
    rows, cols = array.shape
  
  for i in range(rows - input_length - output_length):
    x = array[i:i + input_length, 0:cols]
    y = array[i + input_length:i + input_length + output_length, -1].reshape(output_length, 1)
    X.append(x)
    Y.append(y)
    
  X = np.array(X)
  Y = np.array(Y)
  
  return X, Y

# %%
INPUT_LENGTH = 12 # 48 hours
OUTPUT_LENGTH = 4 # 16 hours

x_tr, y_tr = create_supervised_dataset(tr.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_vl, y_vl = create_supervised_dataset(vl.values, INPUT_LENGTH, OUTPUT_LENGTH)
x_ts, y_ts = create_supervised_dataset(ts.values, INPUT_LENGTH, OUTPUT_LENGTH)

print('Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)')
print(f'Training Set - x_tr: {x_tr.shape}, y_tr: {y_tr.shape}')
print(f'Validation Set - x_vl: {x_vl.shape}, y_vl: {y_vl.shape}')
print(f'Testing Set - x_ts: {x_ts.shape}, y_ts: {y_ts.shape}')
# Out:
# Tamaños entrada (BATCHES x INPUT_LENGTH x FEATURES) y de salida (BATCHES x OUTPUT_LENGTH x FEATURES)
# Training Set - x_tr: (11378, 12, 6), y_tr: (11378, 4, 1)
# Validation Set - x_vl: (1408, 12, 6), y_vl: (1408, 4, 1)
# Testing Set - x_ts: (1409, 12, 6), y_ts: (1409, 4, 1)

# %% [markdown]
# ### 5.3 Escalamiento
#
# Es requerido para garantizar que todas las características se encuentran en el mismo rango de valores, lo que facilita el entrenamiento del modelo y las predicciones:

# %%
from sklearn.preprocessing import MinMaxScaler

def scale_dataset(data_input, col_ref):
  '''Escala el dataset en el rango de -1 a 1.

  Entradas:
  - data_input: diccionario con los dataset de entrada y salida del modelo
  (data_input = {'x_tr':x_tr, 'y_tr':y_tr, 'x_vl':x_vl, 'y_vl':y_vl,
                  'y_ts':y_ts})
  - col_ref: parámetro adicional para especificar la columna que se predicirá
  
  Retorna:
  - data_scaled: diccionario con los datasets de entrada y salida escalados
    (tiene la misma estructura del diccionario de entrada)
  - scaler: el escalador usado (requerido para las predicciones)
  '''
  
  col_ref = df.columns.get_loc(col_ref)
  
  NSAMPLES = data_input['x_tr'].shape[1]
  NFEATS = data_input['x_tr'].shape[2]

  # Generar listado con "scalers" (en este caso, por ser sólo 1 característica
  # se tendrá sólo 1 escalador)
  scalers = [MinMaxScaler(feature_range=(-1,1)) for _ in range(NFEATS)]

  # Arreglos que contendrán los datasets escalados
  x_tr_s = np.zeros(data_input['x_tr'].shape)
  x_vl_s = np.zeros(data_input['x_vl'].shape)
  x_ts_s = np.zeros(data_input['x_ts'].shape)
  y_tr_s = np.zeros(data_input['y_tr'].shape)
  y_vl_s = np.zeros(data_input['y_vl'].shape)
  y_ts_s = np.zeros(data_input['y_ts'].shape)

  # Escalamiento: se usarán los min/max del set de entrenamiento para
  # escalar la totalidad de los datasets

  # Escalamiento Xs: en este caso debemos garantizar que cada dato de entrada
  # a fit_transform o transform debe ser de tamaño nsamples x nfeatures
  # (en este caso 24x13)
  for i in range(NFEATS):
    x_tr_s[:,:,i] = scalers[i].fit_transform(x_tr[:,:,i])
    x_vl_s[:,:,i] = scalers[i].transform(x_vl[:,:,i])
    x_ts_s[:,:,i] = scalers[i].transform(x_ts[:,:,i])
  
  # Escalamiento Ys
  y_tr_s[:,:,0] = scalers[col_ref].fit_transform(y_tr[:,:,0])
  y_vl_s[:,:,0] = scalers[col_ref].transform(y_vl[:,:,0])
  y_ts_s[:,:,0] = scalers[col_ref].transform(y_ts[:,:,0])

  # Conformar diccionario de salida
  data_scaled = {
      'x_tr_s': x_tr_s, 'y_tr_s': y_tr_s,
      'x_vl_s': x_vl_s, 'y_vl_s': y_vl_s,
      'x_ts_s': x_ts_s, 'y_ts_s': y_ts_s,
  }

  return data_scaled, scalers[col_ref]

# %%
# Escalamiento del dataset con la función anterior

# Crear diccionario de entrada
data_in = {
    'x_tr': x_tr, 'y_tr': y_tr,
    'x_vl': x_vl, 'y_vl': y_vl,
    'x_ts': x_ts, 'y_ts': y_ts,
}

# Y escalar
data_s, scaler = scale_dataset(data_in, col_ref='Open')

# Extraer subsets escalados
x_tr_s, y_tr_s = data_s['x_tr_s'], data_s['y_tr_s']
x_vl_s, y_vl_s = data_s['x_vl_s'], data_s['y_vl_s']
x_ts_s, y_ts_s = data_s['x_ts_s'], data_s['y_ts_s']

# Verificación
print(f'Min x_tr/x_vl/x_ts sin escalamiento: {x_tr.min()}/{x_vl.min()}/{x_ts.min()}')
print(f'Min x_tr/x_vl/x_ts con escalamiento: {x_tr_s.min()}/{x_vl_s.min()}/{x_ts_s.min()}')

print(f'\nMin y_tr/y_vl/y_ts sin escalamiento: {y_tr.min()}/{y_vl.min()}/{y_ts.min()}')
print(f'Min y_tr/y_vl/y_ts con escalamiento: {y_tr_s.min()}/{y_vl_s.min()}/{y_ts_s.min()}')

print(f'\nMax x_tr/x_vl/x_ts sin escalamiento: {x_tr.max()}/{x_vl.max()}/{x_ts.max()}')
print(f'Max x_tr/x_vl/x_ts con escalamiento: {x_tr_s.max()}/{x_vl_s.max()}/{x_ts_s.max()}')

print(f'\nMax y_tr/y_vl/y_ts sin escalamiento: {y_tr.max()}/{y_vl.max()}/{y_ts.max()}')
print(f'Max y_tr/y_vl/y_ts con escalamiento: {y_tr_s.max()}/{y_vl_s.max()}/{y_ts_s.max()}')
# Out:
# Min x_tr/x_vl/x_ts sin escalamiento: 0.0/1390.73974/757.14626
# Min x_tr/x_vl/x_ts con escalamiento: -1.0/-0.9902305400988584/-0.9946813125320131
#
# Min y_tr/y_vl/y_ts sin escalamiento: 0.0/60220.0/40087.0
# Min y_tr/y_vl/y_ts con escalamiento: -1.0/-0.9742622350013517/-0.9828669912736496
#
# Max x_tr/x_vl/x_ts sin escalamiento: 4679505.0/4210799.0/1433403.0
# Max x_tr/x_vl/x_ts con escalamiento: 1.0000000000000002/0.7996771025995271/0.8481443236348176
#
# Max y_tr/y_vl/y_ts sin escalamiento: 4679505.0/4210799.0/1433403.0
# Max y_tr/y_vl/y_ts con escalamiento: 0.9999999999999998/0.7996771025995271/-0.38736981796151515

# %% [markdown]
# Generamos una gráfica de tipo violín para ver la distribución de los valores en cada covaraible de entrada y en la varaible a predecir (salida)

# %%
fig, ax = plt.subplots(figsize=(12, 4))
for i in range(1, 6):
  ax.violinplot(dataset=x_tr_s[:,:,i].flatten(), positions=[i])
  ax.violinplot(dataset=x_vl_s[:, :, i].flatten(), positions=[i])
  ax.violinplot(dataset=x_ts_s[:, :, i].flatten(), positions=[i])

ax.set_xticks(list(range(6)))
ax.set_xticklabels(df.keys(), rotation=90)
ax.autoscale()

# %%
fig, ax = plt.subplots(figsize=(6, 4))
ax.violinplot(dataset=y_tr_s.flatten())
ax.violinplot(dataset=y_vl_s.flatten())
ax.violinplot(dataset=y_ts_s.flatten())

ax.set_xticks([1])
ax.set_xticklabels(['y (output)'])
# Out:
# [Text(1, 0, 'y (output)')]

# %% [markdown]
# ## 6. Creación y entrenamiento del modelo
#
# - Entradas: arreglos *x* (batches x input-length  x features = batches x 24 x 1)
# - Salidas: arreglos *y* (batches x output-length x features = batches x 1 x 1)
#
# Usaremos la raíz cuadrada del error cuadrático medio (o RMSE por sus siglas en Inglés: *root mean square error*) como pérdida para entrenar el modelo:
#
# $RMSE = \sqrt{\frac{\sum_i (y_i-\hat{y_i})^2}{N}}$
#
# donde:
# - $y$: temperatura real
# - $\hat{y}$: temperatura predicha
# - $N$: cantidad de predicciones

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import RMSprop
import tensorflow as tf

# Adjust parameters for training
tf.random.set_seed(42)
tf.config.experimental.enable_op_determinism()

# Model
N_UNITS = 128 # Size of hidden layer (h) and the memory cell(c)
INPUT_SHAPE = (x_tr_s.shape[1], x_tr_s.shape[2])

model = Sequential()
model.add(LSTM(N_UNITS, input_shape=INPUT_SHAPE))
model.add(Dense(OUTPUT_LENGTH, activation='linear'))

# loss function
def root_mean_squared_error(y_true, y_pred):
  return tf.math.sqrt(tf.math.reduce_mean(tf.math.square(y_pred - y_true)))

# Compilation
optimizer = RMSprop(learning_rate=5e-5)
model.compile(
  optimizer=optimizer,
  loss=root_mean_squared_error
)

# Training
EPOCHS = 180
BATCH_SIZE = 256
history = model.fit(
  x = x_tr_s, 
  y = y_tr_s,
  batch_size=BATCH_SIZE,
  epochs=EPOCHS,
  validation_data=(x_vl_s, y_vl_s),
  verbose=2
)
# Out:
# Epoch 1/180
# c:\Users\cmglezpdev2\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 45/45 - 2s - 48ms/step - loss: 0.7564 - val_loss: 0.4974
# Epoch 2/180
# 45/45 - 1s - 25ms/step - loss: 0.4964 - val_loss: 0.2796
# Epoch 3/180
# 45/45 - 1s - 23ms/step - loss: 0.2413 - val_loss: 0.1661
# Epoch 4/180
# 45/45 - 1s - 23ms/step - loss: 0.0925 - val_loss: 0.1329
# Epoch 5/180
# 45/45 - 1s - 23ms/step - loss: 0.0600 - val_loss: 0.1309
# Epoch 6/180
# 45/45 - 1s - 23ms/step - loss: 0.0588 - val_loss: 0.1287
# Epoch 7/180
# 45/45 - 1s - 26ms/step - loss: 0.0580 - val_loss: 0.1271
# Epoch 8/180
# 45/45 - 1s - 23ms/step - loss: 0.0574 - val_loss: 0.1258
# Epoch 9/180
# 45/45 - 1s - 23ms/step - loss: 0.0570 - val_loss: 0.1247
# Epoch 10/180
# 45/45 - 1s - 23ms/step - loss: 0.0567 - val_loss: 0.1237
# Epoch 11/180
# 45/45 - 1s - 23ms/step - loss: 0.0565 - val_loss: 0.1228
# Epoch 12/180
# 45/45 - 1s - 22ms/step - loss: 0.0563 - val_loss: 0.1222
# Epoch 13/180
# 45/45 - 1s - 22ms/step - loss: 0.0561 - val_loss: 0.1217
# Epoch 14/180
# 45/45 - 1s - 22ms/step - loss: 0.0560 - val_loss: 0.1213
# Epoch 15/180
# 45/45 - 1s - 22ms/step - loss: 0.0559 - val_loss: 0.1209
# Epoch 16/180
# 45/45 - 1s - 21ms/step - loss: 0.0558 - val_loss: 0.1207
# Epoch 17/180
# 45/45 - 1s - 22ms/step - loss: 0.0557 - val_loss: 0.1204
# Epoch 18/180
# 45/45 - 1s - 22ms/step - loss: 0.0556 - val_loss: 0.1202
# Epoch 19/180
# 45/45 - 1s - 23ms/step - loss: 0.0555 - val_loss: 0.1199
# Epoch 20/180
# 45/45 - 1s - 22ms/step - loss: 0.0554 - val_loss: 0.1197
# Epoch 21/180
# 45/45 - 1s - 23ms/step - loss: 0.0553 - val_loss: 0.1195
# Epoch 22/180
# 45/45 - 1s - 23ms/step - loss: 0.0553 - val_loss: 0.1194
# Epoch 23/180
# 45/45 - 1s - 23ms/step - loss: 0.0552 - val_loss: 0.1192
# Epoch 24/180
# 45/45 - 1s - 23ms/step - loss: 0.0551 - val_loss: 0.1190
# Epoch 25/180
# 45/45 - 1s - 23ms/step - loss: 0.0551 - val_loss: 0.1189
# Epoch 26/180
# 45/45 - 1s - 24ms/step - loss: 0.0550 - val_loss: 0.1187
# Epoch 27/180
# 45/45 - 1s - 26ms/step - loss: 0.0549 - val_loss: 0.1186
# Epoch 28/180
# 45/45 - 1s - 28ms/step - loss: 0.0549 - val_loss: 0.1184
# Epoch 29/180
# 45/45 - 1s - 27ms/step - loss: 0.0548 - val_loss: 0.1183
# Epoch 30/180
# 45/45 - 1s - 25ms/step - loss: 0.0548 - val_loss: 0.1182
# Epoch 31/180
# 45/45 - 2s - 37ms/step - loss: 0.0547 - val_loss: 0.1181
# Epoch 32/180
# 45/45 - 4s - 83ms/step - loss: 0.0546 - val_loss: 0.1180
# Epoch 33/180
# 45/45 - 2s - 52ms/step - loss: 0.0546 - val_loss: 0.1179
# Epoch 34/180
# 45/45 - 2s - 50ms/step - loss: 0.0545 - val_loss: 0.1178
# Epoch 35/180
# 45/45 - 2s - 51ms/step - loss: 0.0545 - val_loss: 0.1177
# Epoch 36/180
# 45/45 - 2s - 50ms/step - loss: 0.0545 - val_loss: 0.1176
# Epoch 37/180
# 45/45 - 2s - 53ms/step - loss: 0.0544 - val_loss: 0.1175
# Epoch 38/180
# 45/45 - 3s - 61ms/step - loss: 0.0544 - val_loss: 0.1174
# Epoch 39/180
# 45/45 - 2s - 50ms/step - loss: 0.0543 - val_loss: 0.1173
# Epoch 40/180
# 45/45 - 2s - 49ms/step - loss: 0.0543 - val_loss: 0.1172
# Epoch 41/180
# 45/45 - 2s - 50ms/step - loss: 0.0542 - val_loss: 0.1171
# Epoch 42/180
# 45/45 - 3s - 58ms/step - loss: 0.0542 - val_loss: 0.1170
# Epoch 43/180
# 45/45 - 2s - 50ms/step - loss: 0.0541 - val_loss: 0.1169
# Epoch 44/180
# 45/45 - 3s - 59ms/step - loss: 0.0541 - val_loss: 0.1169
# Epoch 45/180
# 45/45 - 2s - 51ms/step - loss: 0.0541 - val_loss: 0.1168
# Epoch 46/180
# 45/45 - 3s - 60ms/step - loss: 0.0540 - val_loss: 0.1167
# Epoch 47/180
# 45/45 - 2s - 52ms/step - loss: 0.0540 - val_loss: 0.1167
# Epoch 48/180
# 45/45 - 2s - 52ms/step - loss: 0.0539 - val_loss: 0.1166
# Epoch 49/180
# 45/45 - 2s - 49ms/step - loss: 0.0539 - val_loss: 0.1165
# Epoch 50/180
# 45/45 - 2s - 46ms/step - loss: 0.0539 - val_loss: 0.1165
# Epoch 51/180
# 45/45 - 2s - 49ms/step - loss: 0.0538 - val_loss: 0.1164
# Epoch 52/180
# 45/45 - 2s - 48ms/step - loss: 0.0538 - val_loss: 0.1163
# Epoch 53/180
# 45/45 - 3s - 57ms/step - loss: 0.0538 - val_loss: 0.1163
# Epoch 54/180
# 45/45 - 2s - 52ms/step - loss: 0.0537 - val_loss: 0.1162
# Epoch 55/180
# 45/45 - 2s - 53ms/step - loss: 0.0537 - val_loss: 0.1162
# Epoch 56/180
# 45/45 - 2s - 50ms/step - loss: 0.0537 - val_loss: 0.1161
# Epoch 57/180
# 45/45 - 2s - 53ms/step - loss: 0.0536 - val_loss: 0.1161
# Epoch 58/180
# 45/45 - 2s - 51ms/step - loss: 0.0536 - val_loss: 0.1160
# Epoch 59/180
# 45/45 - 2s - 50ms/step - loss: 0.0536 - val_loss: 0.1160
# Epoch 60/180
# 45/45 - 2s - 50ms/step - loss: 0.0535 - val_loss: 0.1159
# Epoch 61/180
# 45/45 - 2s - 50ms/step - loss: 0.0535 - val_loss: 0.1159
# Epoch 62/180
# 45/45 - 2s - 54ms/step - loss: 0.0535 - val_loss: 0.1158
# Epoch 63/180
# 45/45 - 2s - 55ms/step - loss: 0.0535 - val_loss: 0.1158
# Epoch 64/180
# 45/45 - 2s - 50ms/step - loss: 0.0534 - val_loss: 0.1158
# Epoch 65/180
# 45/45 - 3s - 61ms/step - loss: 0.0534 - val_loss: 0.1157
# Epoch 66/180
# 45/45 - 2s - 52ms/step - loss: 0.0534 - val_loss: 0.1157
# Epoch 67/180
# 45/45 - 2s - 53ms/step - loss: 0.0533 - val_loss: 0.1156
# Epoch 68/180
# 45/45 - 2s - 49ms/step - loss: 0.0533 - val_loss: 0.1156
# Epoch 69/180
# 45/45 - 2s - 49ms/step - loss: 0.0533 - val_loss: 0.1156
# Epoch 70/180
# 45/45 - 2s - 49ms/step - loss: 0.0533 - val_loss: 0.1155
# Epoch 71/180
# 45/45 - 2s - 51ms/step - loss: 0.0532 - val_loss: 0.1155
# Epoch 72/180
# 45/45 - 2s - 51ms/step - loss: 0.0532 - val_loss: 0.1154
# Epoch 73/180
# 45/45 - 2s - 51ms/step - loss: 0.0532 - val_loss: 0.1154
# Epoch 74/180
# 45/45 - 2s - 51ms/step - loss: 0.0532 - val_loss: 0.1153
# Epoch 75/180
# 45/45 - 2s - 52ms/step - loss: 0.0532 - val_loss: 0.1152
# Epoch 76/180
# 45/45 - 2s - 50ms/step - loss: 0.0531 - val_loss: 0.1152
# Epoch 77/180
# 45/45 - 2s - 50ms/step - loss: 0.0531 - val_loss: 0.1151
# Epoch 78/180
# 45/45 - 2s - 48ms/step - loss: 0.0531 - val_loss: 0.1150
# Epoch 79/180
# 45/45 - 2s - 49ms/step - loss: 0.0531 - val_loss: 0.1149
# Epoch 80/180
# 45/45 - 2s - 48ms/step - loss: 0.0531 - val_loss: 0.1148
# Epoch 81/180
# 45/45 - 2s - 49ms/step - loss: 0.0530 - val_loss: 0.1147
# Epoch 82/180
# 45/45 - 3s - 56ms/step - loss: 0.0530 - val_loss: 0.1147
# Epoch 83/180
# 45/45 - 3s - 56ms/step - loss: 0.0530 - val_loss: 0.1146
# Epoch 84/180
# 45/45 - 2s - 51ms/step - loss: 0.0530 - val_loss: 0.1145
# Epoch 85/180
# 45/45 - 2s - 49ms/step - loss: 0.0530 - val_loss: 0.1149
# Epoch 86/180
# 45/45 - 3s - 57ms/step - loss: 0.0529 - val_loss: 0.1146
# Epoch 87/180
# 45/45 - 2s - 47ms/step - loss: 0.0529 - val_loss: 0.1149
# Epoch 88/180
# 45/45 - 3s - 62ms/step - loss: 0.0529 - val_loss: 0.1145
# Epoch 89/180
# 45/45 - 2s - 54ms/step - loss: 0.0529 - val_loss: 0.1149
# Epoch 90/180
# 45/45 - 2s - 48ms/step - loss: 0.0529 - val_loss: 0.1144
# Epoch 91/180
# 45/45 - 2s - 46ms/step - loss: 0.0529 - val_loss: 0.1148
# Epoch 92/180
# 45/45 - 2s - 50ms/step - loss: 0.0528 - val_loss: 0.1144
# Epoch 93/180
# 45/45 - 2s - 52ms/step - loss: 0.0528 - val_loss: 0.1148
# Epoch 94/180
# 45/45 - 2s - 48ms/step - loss: 0.0528 - val_loss: 0.1143
# Epoch 95/180
# 45/45 - 2s - 50ms/step - loss: 0.0528 - val_loss: 0.1147
# Epoch 96/180
# 45/45 - 2s - 47ms/step - loss: 0.0528 - val_loss: 0.1142
# Epoch 97/180
# 45/45 - 2s - 48ms/step - loss: 0.0528 - val_loss: 0.1146
# Epoch 98/180
# 45/45 - 2s - 49ms/step - loss: 0.0528 - val_loss: 0.1142
# Epoch 99/180
# 45/45 - 2s - 47ms/step - loss: 0.0527 - val_loss: 0.1145
# Epoch 100/180
# 45/45 - 2s - 47ms/step - loss: 0.0527 - val_loss: 0.1141
# Epoch 101/180
# 45/45 - 2s - 51ms/step - loss: 0.0527 - val_loss: 0.1143
# Epoch 102/180
# 45/45 - 2s - 49ms/step - loss: 0.0527 - val_loss: 0.1140
# Epoch 103/180
# 45/45 - 2s - 51ms/step - loss: 0.0527 - val_loss: 0.1141
# Epoch 104/180
# 45/45 - 2s - 48ms/step - loss: 0.0527 - val_loss: 0.1140
# Epoch 105/180
# 45/45 - 2s - 48ms/step - loss: 0.0526 - val_loss: 0.1141
# Epoch 106/180
# 45/45 - 2s - 47ms/step - loss: 0.0526 - val_loss: 0.1139
# Epoch 107/180
# 45/45 - 2s - 49ms/step - loss: 0.0527 - val_loss: 0.1139
# Epoch 108/180
# 45/45 - 2s - 50ms/step - loss: 0.0526 - val_loss: 0.1139
# Epoch 109/180
# 45/45 - 2s - 48ms/step - loss: 0.0526 - val_loss: 0.1138
# Epoch 110/180
# 45/45 - 2s - 51ms/step - loss: 0.0526 - val_loss: 0.1138
# Epoch 111/180
# 45/45 - 2s - 48ms/step - loss: 0.0526 - val_loss: 0.1137
# Epoch 112/180
# 45/45 - 2s - 49ms/step - loss: 0.0526 - val_loss: 0.1138
# Epoch 113/180
# 45/45 - 3s - 57ms/step - loss: 0.0526 - val_loss: 0.1137
# Epoch 114/180
# 45/45 - 2s - 48ms/step - loss: 0.0525 - val_loss: 0.1142
# Epoch 115/180
# 45/45 - 2s - 48ms/step - loss: 0.0525 - val_loss: 0.1137
# Epoch 116/180
# 45/45 - 2s - 49ms/step - loss: 0.0525 - val_loss: 0.1136
# Epoch 117/180
# 45/45 - 3s - 57ms/step - loss: 0.0525 - val_loss: 0.1137
# Epoch 118/180
# 45/45 - 3s - 59ms/step - loss: 0.0525 - val_loss: 0.1136
# Epoch 119/180
# 45/45 - 2s - 49ms/step - loss: 0.0525 - val_loss: 0.1136
# Epoch 120/180
# 45/45 - 3s - 59ms/step - loss: 0.0525 - val_loss: 0.1135
# Epoch 121/180
# 45/45 - 2s - 50ms/step - loss: 0.0525 - val_loss: 0.1136
# Epoch 122/180
# 45/45 - 2s - 48ms/step - loss: 0.0525 - val_loss: 0.1136
# Epoch 123/180
# 45/45 - 2s - 52ms/step - loss: 0.0525 - val_loss: 0.1135
# Epoch 124/180
# 45/45 - 2s - 49ms/step - loss: 0.0525 - val_loss: 0.1135
# Epoch 125/180
# 45/45 - 2s - 48ms/step - loss: 0.0524 - val_loss: 0.1135
# Epoch 126/180
# 45/45 - 2s - 50ms/step - loss: 0.0524 - val_loss: 0.1135
# Epoch 127/180
# 45/45 - 2s - 50ms/step - loss: 0.0524 - val_loss: 0.1134
# Epoch 128/180
# 45/45 - 2s - 47ms/step - loss: 0.0524 - val_loss: 0.1134
# Epoch 129/180
# 45/45 - 2s - 46ms/step - loss: 0.0524 - val_loss: 0.1134
# Epoch 130/180
# 45/45 - 2s - 46ms/step - loss: 0.0524 - val_loss: 0.1133
# Epoch 131/180
# 45/45 - 2s - 47ms/step - loss: 0.0524 - val_loss: 0.1135
# Epoch 132/180
# 45/45 - 2s - 47ms/step - loss: 0.0524 - val_loss: 0.1133
# Epoch 133/180
# 45/45 - 2s - 46ms/step - loss: 0.0524 - val_loss: 0.1133
# Epoch 134/180
# 45/45 - 2s - 46ms/step - loss: 0.0524 - val_loss: 0.1133
# Epoch 135/180
# 45/45 - 2s - 46ms/step - loss: 0.0523 - val_loss: 0.1133
# Epoch 136/180
# 45/45 - 2s - 46ms/step - loss: 0.0523 - val_loss: 0.1133
# Epoch 137/180
# 45/45 - 2s - 47ms/step - loss: 0.0523 - val_loss: 0.1132
# Epoch 138/180
# 45/45 - 2s - 46ms/step - loss: 0.0523 - val_loss: 0.1132
# Epoch 139/180
# 45/45 - 2s - 49ms/step - loss: 0.0523 - val_loss: 0.1132
# Epoch 140/180
# 45/45 - 2s - 55ms/step - loss: 0.0523 - val_loss: 0.1132
# Epoch 141/180
# 45/45 - 3s - 74ms/step - loss: 0.0523 - val_loss: 0.1132
# Epoch 142/180
# 45/45 - 2s - 50ms/step - loss: 0.0523 - val_loss: 0.1131
# Epoch 143/180
# 45/45 - 2s - 50ms/step - loss: 0.0523 - val_loss: 0.1131
# Epoch 144/180
# 45/45 - 2s - 49ms/step - loss: 0.0523 - val_loss: 0.1131
# Epoch 145/180
# 45/45 - 2s - 49ms/step - loss: 0.0523 - val_loss: 0.1131
# Epoch 146/180
# 45/45 - 2s - 50ms/step - loss: 0.0523 - val_loss: 0.1131
# Epoch 147/180
# 45/45 - 2s - 49ms/step - loss: 0.0523 - val_loss: 0.1130
# Epoch 148/180
# 45/45 - 2s - 48ms/step - loss: 0.0523 - val_loss: 0.1130
# Epoch 149/180
# 45/45 - 2s - 50ms/step - loss: 0.0523 - val_loss: 0.1130
# Epoch 150/180
# 45/45 - 2s - 50ms/step - loss: 0.0522 - val_loss: 0.1130
# Epoch 151/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1130
# Epoch 152/180
# 45/45 - 2s - 50ms/step - loss: 0.0522 - val_loss: 0.1130
# Epoch 153/180
# 45/45 - 2s - 48ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 154/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 155/180
# 45/45 - 2s - 48ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 156/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 157/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 158/180
# 45/45 - 2s - 53ms/step - loss: 0.0522 - val_loss: 0.1129
# Epoch 159/180
# 45/45 - 2s - 51ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 160/180
# 45/45 - 2s - 47ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 161/180
# 45/45 - 2s - 51ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 162/180
# 45/45 - 2s - 46ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 163/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 164/180
# 45/45 - 2s - 48ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 165/180
# 45/45 - 3s - 61ms/step - loss: 0.0522 - val_loss: 0.1128
# Epoch 166/180
# 45/45 - 2s - 49ms/step - loss: 0.0522 - val_loss: 0.1127
# Epoch 167/180
# 45/45 - 2s - 47ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 168/180
# 45/45 - 2s - 48ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 169/180
# 45/45 - 2s - 47ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 170/180
# 45/45 - 2s - 49ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 171/180
# 45/45 - 2s - 46ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 172/180
# 45/45 - 2s - 47ms/step - loss: 0.0521 - val_loss: 0.1127
# Epoch 173/180
# 45/45 - 3s - 59ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 174/180
# 45/45 - 2s - 48ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 175/180
# 45/45 - 3s - 58ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 176/180
# 45/45 - 2s - 48ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 177/180
# 45/45 - 2s - 49ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 178/180
# 45/45 - 2s - 48ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 179/180
# 45/45 - 2s - 48ms/step - loss: 0.0521 - val_loss: 0.1126
# Epoch 180/180
# 45/45 - 2s - 47ms/step - loss: 0.0521 - val_loss: 0.1126

# %%
# Plot training and validation curves to check that there is no overfitting
plt.plot(history.history['loss'], label='RMSE train')
plt.plot(history.history['val_loss'], label='RMSE val')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()

# %% [markdown]
# **Observaciones y sugerencias:**
#
# - El modelo con entradas multivariadas parece tener un desempeño inferior en comparación con los modelos univariados (RMSEs del orden del 10% vs 1-2% en los casos anteriores)
# - Lo anterior puede indicar:
#   - Que el uso de multivariables podría empeorar la predicción
#   - Que no todas las variables son relevantes
#   - Sugerencia: jacer un análisis de relevancia de las variables (_feature importance_) y entrenar el modelo solo con aquellas más relevantes.
# - Se sugiere afinar el modelo modificando varios de sus hiperparámetros y usando técnicas como, por ejemplo, *random grid search*. Los hiperparámetros a afinar pueden ser:
#   - *INPUT_LENGTH* (esto implica modificar la fase de pre-procesamiento)
#   - Número de unidades de la Red LSTM
#   - Pérdida
#   - Tasa de aprendizaje
#   - Epochs
#   - Batch size

# %% [markdown]
# ### Desempeño del modelo

# %%
rmse_tr = model.evaluate(x_tr_s, y_tr_s, verbose=0)
rmse_vl = model.evaluate(x_vl_s, y_vl_s, verbose=0)
rmse_ts = model.evaluate(x_ts_s, y_ts_s, verbose=0)

print('Performances:')
print('\tTrain RMSE: %.3f' % rmse_tr)
print('\tValidation RMSE: %.3f' % rmse_vl)
print('\tTest RMSE: %.3f' % rmse_ts)
# Out:
# Performances:
# 	Train RMSE: 0.036
# 	Validation RMSE: 0.110
# 	Test RMSE: 0.045

# %% [markdown]
# Los desempeños son comparables lo cual quiere decir que el modelo generaliza bastante bien.

# %%
# Generate predictions over test set
y_ts_pred_s = model.predict(x_ts_s, verbose=0)
y_ts_pred = scaler.inverse_transform(y_ts_pred_s)

# calc RMSE for each predicted instants of time
diff_square = np.square(y_ts.squeeze() - y_ts_pred)
proms = np.mean(diff_square, axis=0)
rmse = np.sqrt(proms)

t = np.linspace(1, 4, 4)

fig, ax = plt.subplots()
ax.scatter(t, rmse)
ax.set_xlabel('Forecast')
ax.set_ylabel('Error RMSE')
plt.xticks(ticks=t, labels=t)
plt.grid()

# %% [markdown]
# ### Predicciones con el modelo entrenado

# %%
def predict(x, model, scaler):
  '''Genera la predicción de OUTPUT_LENGTH instantes
  de tiempo a futuro con el modelo entrenado.

  Entrada:
  - x: batch (o batches) de datos para ingresar al modelo
    (tamaño: BATCHES X INPUT_LENGTH X FEATURES)
  - model: Red LSTM entrenada
  - scaler: escalador (requerido para llevar la predicción a la escala original)
  
  Salida:
  - y_pred: la predicción en la escala original (tamaño: BATCHES X OUTPUT_LENGTH X FEATURES)
  '''
    
  y_pred_s = model.predict(x, verbose=0)
  y_pred = scaler.inverse_transform(y_pred_s)
  
  return y_pred.flatten()

# %%
# Calculate predictions over testing dataset
y_ts_pred = predict(x_ts_s, model, scaler)

# %% [markdown]
# Analicemos este desempeño gráficamente mostrando los precios originales y las predichas por el modelo para cada uno de los datos del set de prueba:

# %%
N = len(y_ts_pred)
ndata = np.linspace(1, N, N)

errors = y_ts.flatten() - y_ts_pred.flatten()
plt.plot(errors)

# %% [markdown]
# Se observa que:
# - EL promedio de errors es cercano a cero.
# - Hay bastantes instantes de tiempo donde se alcanzan errores de hasta -2000 y 3000 dólares de diferencia.
